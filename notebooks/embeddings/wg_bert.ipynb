# %%
import sys
import os

# Get the absolute path of the project root (adjust as needed)
project_root = os.path.abspath("../..")  # Moves one level up to project root

# Add to sys.path if not already present
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# %pip install transformers torch
# Out:
# Collecting transformers
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.8 MB/s eta 0:00:00
# Collecting torch
#   Using cached torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting filelock (from transformers)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.26.0 (from transformers)
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from transformers) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /root/fast-api-graph/venv/lib/python3.12/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from torch) (3.1.5)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Using cached triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /root/fast-api-graph/venv/lib/python3.12/site-packages (from torch) (75.8.0)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/fast-api-graph/venv/lib/python3.12/site-packages (from requests->transformers) (2025.1.31)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 70.6 MB/s eta 0:00:00:00:010:01
# Using cached torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl (766.6 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 31.4 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 18.6 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 26.8 MB/s eta 0:00:00
# Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 61.0 MB/s eta 0:00:00:00:01
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, sympy, safetensors, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cudnn-cu12, huggingface-hub, tokenizers, nvidia-cusolver-cu12, transformers, torch
# Successfully installed filelock-3.18.0 fsspec-2025.3.0 huggingface-hub-0.29.3 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 safetensors-0.5.3 sympy-1.13.1 tokenizers-0.21.1 torch-2.6.0 transformers-4.49.0 triton-3.2.0
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")  # Debugging

# Load model from Hugging Face Hub
model_name = "lukasweber/WG_BERT"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name, ignore_mismatched_sizes=True)  

# Move model to GPU
model.to(device)

def get_bert_embeddings(text):
    """Generate sentence embeddings using a BERT model."""
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

    # Move inputs to GPU
    inputs = {key: value.to(device) for key, value in inputs.items()}  # ✅ Move input tensors

    with torch.no_grad():
        outputs = model(**inputs)

    # Extract mean-pooled embeddings
    embeddings = outputs.last_hidden_state.mean(dim=1)

    # Move embeddings back to CPU and convert to list
    return embeddings.cpu().squeeze(0).tolist()

# Example usage
text = "Hello, how are you?"
embedding = get_bert_embeddings(text)
print(len(embedding))  # Expected output: 768 (correct dimension)
# Out:
# Using device: cuda
# Some weights of BertModel were not initialized from the model checkpoint at lukasweber/WG_BERT and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 768

# %%
from database.database import qclient
from qdrant_client import QdrantClient, models

COLLECTION_NAME = "wg_bert_embeddings"
# Create a collection if it doesn't already exist
if not qclient.collection_exists(COLLECTION_NAME):
    qclient.create_collection(
        collection_name=COLLECTION_NAME,
        vectors_config=models.VectorParams(
            size=embedding.shape[1], distance=models.Distance.COSINE
        ),
    )

# %%
import uuid
from utils import get_tokens


def create_component_vector(name, description, ecu_system):
    text = " ".join(get_tokens(name + "\n" + description))

    # Get BERT embedding as a Python list
    embeddings = (
        get_bert_embeddings(text).squeeze(0).tolist()
    )  # ✅ Convert tensor → list

    # Insert into Qdrant
    qclient.upsert(
        collection_name=COLLECTION_NAME,
        points=[
            models.PointStruct(
                id=str(uuid.uuid4()),
                vector=embeddings,  # ✅ Now correctly formatted as a list
                payload={
                    "name": name,
                    "description": description,
                    "type": "Component",
                    "ecu_system": ecu_system,
                },
            )
        ],
    )

# %%
from database.database import get_all_components, driver

# get all components for the CCU1
with driver.session() as session:
    all_components = session.execute_read(get_all_components, "CCU1")
    for component in all_components:
        print(component)
        create_component_vector(component["name"], component["description"], "CCU1")
# Out:
# <Record name='C24' description='Connector, 21-pole' file_id=None purpose=None more_description=None>
# <Record name='C78' description='Connector, 21-pole' file_id=None purpose=None more_description=None>
# <Record name='C285' description='Splice, door driver' file_id=None purpose=None more_description=None>
# <Record name='C8052' description='Splice, ground, external' file_id=None purpose=None more_description=None>
# <Record name='C8056' description='Splice, B' file_id=None purpose=None more_description=None>
# <Record name='C8068' description='Connector, 6-pole' file_id=None purpose=None more_description=None>
# <Record name='C8069' description='Connector, 6-pole' file_id=None purpose=None more_description=None>
# <Record name='E106' description='Control unit, DCS, driver' file_id=None purpose=None more_description=None>
# <Record name='E107' description='Control unit, DCS, passenger' file_id=None purpose=None more_description=None>
# <Record name='G8-3' description='Splice, ground' file_id=None purpose=None more_description=None>
# <Record name='G64-2' description='Splice, ground' file_id=None purpose=None more_description=None>
# <Record name='L32' description='Lamp, boarding step, driver/passenger' file_id=None purpose=None more_description=None>
# <Record name='L33' description='Lamp, boarding step, driver/passenger' file_id=None purpose=None more_description=None>
# <Record name='L56' description='Lamp, bed, lower, driver' file_id=None purpose=None more_description=None>
# <Record name='C26' description='Connector 16-pole' file_id=None purpose=None more_description=None>
# <Record name='C8046' description='Connector, 9-pole, HVAC' file_id=None purpose=None more_description=None>
# <Record name='C8099' description='Splice, sub CAN H' file_id=None purpose=None more_description=None>
# <Record name='C8100' description='Splice, sub CAN L' file_id=None purpose=None more_description=None>
# <Record name='C8331' description='Splice, Second wake up passenger side' file_id=None purpose=None more_description=None>
# <Record name='D73' description='Resistor, termination 120 Ohm' file_id=None purpose=None more_description=None>
# <Record name='G2-3' description='Splice, ground' file_id=None purpose=None more_description=None>
# <Record name='G3-2' description='Splice, ground' file_id=None purpose=None more_description=None>
# <Record name='GND' description='Splice' file_id=None purpose=None more_description=None>
# <Record name='P2.BX13' description='Fuse socket, central electric unit' file_id=None purpose=None more_description=None>
# <Record name='P2.BX33' description='Fuse socket, central electric unit' file_id=None purpose=None more_description=None>
# <Record name='POW' description='Splice' file_id=None purpose=None more_description=None>

# %% [markdown]
# #### IO List Processing

# %%
import os
from xmltodict import parse

file_content = None
# calculate the hash of the file
with open(f"../../data/input/io_lists/PtIOList_COO.xml", "rb") as file:
    file_content = file.read()
    # parse the xml file content to a dictionary
    pt_io_list = parse(file_content)
    io_list = []
    if "IO" in pt_io_list["PtIOList"] and type(pt_io_list["PtIOList"]["IO"]) == list:
        for io in pt_io_list["PtIOList"]["IO"]:
            io_list.append(io)
    elif "IO" in pt_io_list["PtIOList"]:
        io_list.append(pt_io_list["PtIOList"]["IO"])

    print(f"Processing IO Mapping - total IOs: {len(io_list)}")
# Out:
# Processing IO Mapping - total IOs: 658

# %%
from utils import get_clean_io_name

def get_io_tokens(io):
    description = ""
    name_presentation = ""
    name = io["Name"]
    if "NamePresentation" in io and "#text" in io["NamePresentation"]:
        name_presentation = io["NamePresentation"]["#text"]

    if "Description" in io["IOService"] and "#text" in io["IOService"]["Description"]:
        description = io["IOService"]["Description"]["#text"]

    if name == name_presentation:
        name_presentation = ""  # if name and name_presentation are the same, we don't need to repeat the name_presentation

    data = get_clean_io_name(name) + "\n" + name_presentation + "\n" + description

    tokens = get_tokens(data)

    # make tokens unique
    tokens = list(set(tokens))

    return tokens

# %%
def get_points(embeddings, ecu_system, collection_name):
    response = qclient.query_points(
        collection_name=collection_name,
        query=embeddings,
        query_filter=models.Filter(
            must=[
                models.FieldCondition(
                    key="ecu_system",
                    match=models.MatchValue(
                        value=ecu_system,
                    ),
                )
            ],
        ),
    )

    points = response.points

    return points

# %%
from database.database import oclient


def get_nomic_embeddings(text):
    embeddings_response = oclient.embeddings(model="nomic-embed-text", prompt=text)
    embeddings = embeddings_response["embedding"]

    return embeddings

# %%
import pandas as pd
from database.database import qclient

io_df = pd.DataFrame(
    columns=[
        "IO Mapping",
        "Description",
        "Embedding",
        "Component Name",
        "Component Description",
        "Score",
    ]
)


# loop with enumerate to get the index of the IO
for idx, io in enumerate(io_list):
    print(f"Processing IO Mapping - IO: {idx + 1}")
    tokens = get_io_tokens(io)
    text = " ".join(tokens)
    embeddings = get_bert_embeddings(text)

    name_presentation = ""
    name = io["Name"]
    if "NamePresentation" in io and "#text" in io["NamePresentation"]:
        name_presentation = io["NamePresentation"]["#text"]

    points = get_points(embeddings, "CCU1", COLLECTION_NAME)

    for point in points[:3]:
        row = {
            "IO Mapping": name,
            "Description": name_presentation,
            "Embedding": "WG_BERT",
            "Component Name": point.payload["name"],
            "Component Description": point.payload["description"],
            "Score": point.score,
        }

        io_df.loc[len(io_df)] = row

    # nomic embeddings
    embeddings = get_nomic_embeddings(text)

    points = get_points(embeddings, "CCU1", "components")

    for point in points[:3]:
        row = {
            "IO Mapping": name,
            "Description": name_presentation,
            "Embedding": "NOMIC",
            "Component Name": point.payload["name"],
            "Component Description": point.payload["description"],
            "Score": point.score,
        }

        io_df.loc[len(io_df)] = row


io_df.to_csv("../../data/output/io_mapping_ccu1.csv", index=False)
# Out:
# Processing IO Mapping - IO: 1
# Processing IO Mapping - IO: 2
# Processing IO Mapping - IO: 3
# Processing IO Mapping - IO: 4
# Processing IO Mapping - IO: 5
# Processing IO Mapping - IO: 6
# Processing IO Mapping - IO: 7
# Processing IO Mapping - IO: 8
# Processing IO Mapping - IO: 9
# Processing IO Mapping - IO: 10
# Processing IO Mapping - IO: 11
# Processing IO Mapping - IO: 12
# Processing IO Mapping - IO: 13
# Processing IO Mapping - IO: 14
# Processing IO Mapping - IO: 15
# Processing IO Mapping - IO: 16
# Processing IO Mapping - IO: 17
# Processing IO Mapping - IO: 18
# Processing IO Mapping - IO: 19
# Processing IO Mapping - IO: 20
# Processing IO Mapping - IO: 21
# Processing IO Mapping - IO: 22
# Processing IO Mapping - IO: 23
# Processing IO Mapping - IO: 24
# Processing IO Mapping - IO: 25
# Processing IO Mapping - IO: 26
# Processing IO Mapping - IO: 27
# Processing IO Mapping - IO: 28
# Processing IO Mapping - IO: 29
# Processing IO Mapping - IO: 30
# Processing IO Mapping - IO: 31
# Processing IO Mapping - IO: 32
# Processing IO Mapping - IO: 33
# Processing IO Mapping - IO: 34
# Processing IO Mapping - IO: 35
# Processing IO Mapping - IO: 36
# Processing IO Mapping - IO: 37
# Processing IO Mapping - IO: 38
# Processing IO Mapping - IO: 39
# Processing IO Mapping - IO: 40
# Processing IO Mapping - IO: 41
# Processing IO Mapping - IO: 42
# Processing IO Mapping - IO: 43
# Processing IO Mapping - IO: 44
# Processing IO Mapping - IO: 45
# Processing IO Mapping - IO: 46
# Processing IO Mapping - IO: 47
# Processing IO Mapping - IO: 48
# Processing IO Mapping - IO: 49
# Processing IO Mapping - IO: 50
# Processing IO Mapping - IO: 51
# Processing IO Mapping - IO: 52
# Processing IO Mapping - IO: 53
# Processing IO Mapping - IO: 54
# Processing IO Mapping - IO: 55
# Processing IO Mapping - IO: 56
# Processing IO Mapping - IO: 57
# Processing IO Mapping - IO: 58
# Processing IO Mapping - IO: 59
# Processing IO Mapping - IO: 60
# Processing IO Mapping - IO: 61
# Processing IO Mapping - IO: 62
# Processing IO Mapping - IO: 63
# Processing IO Mapping - IO: 64
# Processing IO Mapping - IO: 65
# Processing IO Mapping - IO: 66
# Processing IO Mapping - IO: 67
# Processing IO Mapping - IO: 68
# Processing IO Mapping - IO: 69
# Processing IO Mapping - IO: 70
# Processing IO Mapping - IO: 71
# Processing IO Mapping - IO: 72
# Processing IO Mapping - IO: 73
# Processing IO Mapping - IO: 74
# Processing IO Mapping - IO: 75
# Processing IO Mapping - IO: 76
# Processing IO Mapping - IO: 77
# Processing IO Mapping - IO: 78
# Processing IO Mapping - IO: 79
# Processing IO Mapping - IO: 80
# Processing IO Mapping - IO: 81
# Processing IO Mapping - IO: 82
# Processing IO Mapping - IO: 83
# Processing IO Mapping - IO: 84
# Processing IO Mapping - IO: 85
# Processing IO Mapping - IO: 86
# Processing IO Mapping - IO: 87
# Processing IO Mapping - IO: 88
# Processing IO Mapping - IO: 89
# Processing IO Mapping - IO: 90
# Processing IO Mapping - IO: 91
# Processing IO Mapping - IO: 92
# Processing IO Mapping - IO: 93
# Processing IO Mapping - IO: 94
# Processing IO Mapping - IO: 95
# Processing IO Mapping - IO: 96
# Processing IO Mapping - IO: 97
# Processing IO Mapping - IO: 98
# Processing IO Mapping - IO: 99
# Processing IO Mapping - IO: 100
# Processing IO Mapping - IO: 101
# Processing IO Mapping - IO: 102
# Processing IO Mapping - IO: 103
# Processing IO Mapping - IO: 104
# Processing IO Mapping - IO: 105
# Processing IO Mapping - IO: 106
# Processing IO Mapping - IO: 107
# Processing IO Mapping - IO: 108
# Processing IO Mapping - IO: 109
# Processing IO Mapping - IO: 110
# Processing IO Mapping - IO: 111
# Processing IO Mapping - IO: 112
# Processing IO Mapping - IO: 113
# Processing IO Mapping - IO: 114
# Processing IO Mapping - IO: 115
# Processing IO Mapping - IO: 116
# Processing IO Mapping - IO: 117
# Processing IO Mapping - IO: 118
# Processing IO Mapping - IO: 119
# Processing IO Mapping - IO: 120
# Processing IO Mapping - IO: 121
# Processing IO Mapping - IO: 122
# Processing IO Mapping - IO: 123
# Processing IO Mapping - IO: 124
# Processing IO Mapping - IO: 125
# Processing IO Mapping - IO: 126
# Processing IO Mapping - IO: 127
# Processing IO Mapping - IO: 128
# Processing IO Mapping - IO: 129
# Processing IO Mapping - IO: 130
# Processing IO Mapping - IO: 131
# Processing IO Mapping - IO: 132
# Processing IO Mapping - IO: 133
# Processing IO Mapping - IO: 134
# Processing IO Mapping - IO: 135
# Processing IO Mapping - IO: 136
# Processing IO Mapping - IO: 137
# Processing IO Mapping - IO: 138
# Processing IO Mapping - IO: 139
# Processing IO Mapping - IO: 140
# Processing IO Mapping - IO: 141
# Processing IO Mapping - IO: 142
# Processing IO Mapping - IO: 143
# Processing IO Mapping - IO: 144
# Processing IO Mapping - IO: 145
# Processing IO Mapping - IO: 146
# Processing IO Mapping - IO: 147
# Processing IO Mapping - IO: 148
# Processing IO Mapping - IO: 149
# Processing IO Mapping - IO: 150
# Processing IO Mapping - IO: 151
# Processing IO Mapping - IO: 152
# Processing IO Mapping - IO: 153
# Processing IO Mapping - IO: 154
# Processing IO Mapping - IO: 155
# Processing IO Mapping - IO: 156
# Processing IO Mapping - IO: 157
# Processing IO Mapping - IO: 158
# Processing IO Mapping - IO: 159
# Processing IO Mapping - IO: 160
# Processing IO Mapping - IO: 161
# Processing IO Mapping - IO: 162
# Processing IO Mapping - IO: 163
# Processing IO Mapping - IO: 164
# Processing IO Mapping - IO: 165
# Processing IO Mapping - IO: 166
# Processing IO Mapping - IO: 167
# Processing IO Mapping - IO: 168
# Processing IO Mapping - IO: 169
# Processing IO Mapping - IO: 170
# Processing IO Mapping - IO: 171
# Processing IO Mapping - IO: 172
# Processing IO Mapping - IO: 173
# Processing IO Mapping - IO: 174
# Processing IO Mapping - IO: 175
# Processing IO Mapping - IO: 176
# Processing IO Mapping - IO: 177
# Processing IO Mapping - IO: 178
# Processing IO Mapping - IO: 179
# Processing IO Mapping - IO: 180
# Processing IO Mapping - IO: 181
# Processing IO Mapping - IO: 182
# Processing IO Mapping - IO: 183
# Processing IO Mapping - IO: 184
# Processing IO Mapping - IO: 185
# Processing IO Mapping - IO: 186
# Processing IO Mapping - IO: 187
# Processing IO Mapping - IO: 188
# Processing IO Mapping - IO: 189
# Processing IO Mapping - IO: 190
# Processing IO Mapping - IO: 191
# Processing IO Mapping - IO: 192
# Processing IO Mapping - IO: 193
# Processing IO Mapping - IO: 194
# Processing IO Mapping - IO: 195
# Processing IO Mapping - IO: 196
# Processing IO Mapping - IO: 197
# Processing IO Mapping - IO: 198
# Processing IO Mapping - IO: 199
# Processing IO Mapping - IO: 200
# Processing IO Mapping - IO: 201
# Processing IO Mapping - IO: 202
# Processing IO Mapping - IO: 203
# Processing IO Mapping - IO: 204
# Processing IO Mapping - IO: 205
# Processing IO Mapping - IO: 206
# Processing IO Mapping - IO: 207
# Processing IO Mapping - IO: 208
# Processing IO Mapping - IO: 209
# Processing IO Mapping - IO: 210
# Processing IO Mapping - IO: 211
# Processing IO Mapping - IO: 212
# Processing IO Mapping - IO: 213
# Processing IO Mapping - IO: 214
# Processing IO Mapping - IO: 215
# Processing IO Mapping - IO: 216
# Processing IO Mapping - IO: 217
# Processing IO Mapping - IO: 218
# Processing IO Mapping - IO: 219
# Processing IO Mapping - IO: 220
# Processing IO Mapping - IO: 221
# Processing IO Mapping - IO: 222
# Processing IO Mapping - IO: 223
# Processing IO Mapping - IO: 224
# Processing IO Mapping - IO: 225
# Processing IO Mapping - IO: 226
# Processing IO Mapping - IO: 227
# Processing IO Mapping - IO: 228
# Processing IO Mapping - IO: 229
# Processing IO Mapping - IO: 230
# Processing IO Mapping - IO: 231
# Processing IO Mapping - IO: 232
# Processing IO Mapping - IO: 233
# Processing IO Mapping - IO: 234
# Processing IO Mapping - IO: 235
# Processing IO Mapping - IO: 236
# Processing IO Mapping - IO: 237
# Processing IO Mapping - IO: 238
# Processing IO Mapping - IO: 239
# Processing IO Mapping - IO: 240
# Processing IO Mapping - IO: 241
# Processing IO Mapping - IO: 242
# Processing IO Mapping - IO: 243
# Processing IO Mapping - IO: 244
# Processing IO Mapping - IO: 245
# Processing IO Mapping - IO: 246
# Processing IO Mapping - IO: 247
# Processing IO Mapping - IO: 248
# Processing IO Mapping - IO: 249
# Processing IO Mapping - IO: 250
# Processing IO Mapping - IO: 251
# Processing IO Mapping - IO: 252
# Processing IO Mapping - IO: 253
# Processing IO Mapping - IO: 254
# Processing IO Mapping - IO: 255
# Processing IO Mapping - IO: 256
# Processing IO Mapping - IO: 257
# Processing IO Mapping - IO: 258
# Processing IO Mapping - IO: 259
# Processing IO Mapping - IO: 260
# Processing IO Mapping - IO: 261
# Processing IO Mapping - IO: 262
# Processing IO Mapping - IO: 263
# Processing IO Mapping - IO: 264
# Processing IO Mapping - IO: 265
# Processing IO Mapping - IO: 266
# Processing IO Mapping - IO: 267
# Processing IO Mapping - IO: 268
# Processing IO Mapping - IO: 269
# Processing IO Mapping - IO: 270
# Processing IO Mapping - IO: 271
# Processing IO Mapping - IO: 272
# Processing IO Mapping - IO: 273
# Processing IO Mapping - IO: 274
# Processing IO Mapping - IO: 275
# Processing IO Mapping - IO: 276
# Processing IO Mapping - IO: 277
# Processing IO Mapping - IO: 278
# Processing IO Mapping - IO: 279
# Processing IO Mapping - IO: 280
# Processing IO Mapping - IO: 281
# Processing IO Mapping - IO: 282
# Processing IO Mapping - IO: 283
# Processing IO Mapping - IO: 284
# Processing IO Mapping - IO: 285
# Processing IO Mapping - IO: 286
# Processing IO Mapping - IO: 287
# Processing IO Mapping - IO: 288
# Processing IO Mapping - IO: 289
# Processing IO Mapping - IO: 290
# Processing IO Mapping - IO: 291
# Processing IO Mapping - IO: 292
# Processing IO Mapping - IO: 293
# Processing IO Mapping - IO: 294
# Processing IO Mapping - IO: 295
# Processing IO Mapping - IO: 296
# Processing IO Mapping - IO: 297
# Processing IO Mapping - IO: 298
# Processing IO Mapping - IO: 299
# Processing IO Mapping - IO: 300
# Processing IO Mapping - IO: 301
# Processing IO Mapping - IO: 302
# Processing IO Mapping - IO: 303
# Processing IO Mapping - IO: 304
# Processing IO Mapping - IO: 305
# Processing IO Mapping - IO: 306
# Processing IO Mapping - IO: 307
# Processing IO Mapping - IO: 308
# Processing IO Mapping - IO: 309
# Processing IO Mapping - IO: 310
# Processing IO Mapping - IO: 311
# Processing IO Mapping - IO: 312
# Processing IO Mapping - IO: 313
# Processing IO Mapping - IO: 314
# Processing IO Mapping - IO: 315
# Processing IO Mapping - IO: 316
# Processing IO Mapping - IO: 317
# Processing IO Mapping - IO: 318
# Processing IO Mapping - IO: 319
# Processing IO Mapping - IO: 320
# Processing IO Mapping - IO: 321
# Processing IO Mapping - IO: 322
# Processing IO Mapping - IO: 323
# Processing IO Mapping - IO: 324
# Processing IO Mapping - IO: 325
# Processing IO Mapping - IO: 326
# Processing IO Mapping - IO: 327
# Processing IO Mapping - IO: 328
# Processing IO Mapping - IO: 329
# Processing IO Mapping - IO: 330
# Processing IO Mapping - IO: 331
# Processing IO Mapping - IO: 332
# Processing IO Mapping - IO: 333
# Processing IO Mapping - IO: 334
# Processing IO Mapping - IO: 335
# Processing IO Mapping - IO: 336
# Processing IO Mapping - IO: 337
# Processing IO Mapping - IO: 338
# Processing IO Mapping - IO: 339
# Processing IO Mapping - IO: 340
# Processing IO Mapping - IO: 341
# Processing IO Mapping - IO: 342
# Processing IO Mapping - IO: 343
# Processing IO Mapping - IO: 344
# Processing IO Mapping - IO: 345
# Processing IO Mapping - IO: 346
# Processing IO Mapping - IO: 347
# Processing IO Mapping - IO: 348
# Processing IO Mapping - IO: 349
# Processing IO Mapping - IO: 350
# Processing IO Mapping - IO: 351
# Processing IO Mapping - IO: 352
# Processing IO Mapping - IO: 353
# Processing IO Mapping - IO: 354
# Processing IO Mapping - IO: 355
# Processing IO Mapping - IO: 356
# Processing IO Mapping - IO: 357
# Processing IO Mapping - IO: 358
# Processing IO Mapping - IO: 359
# Processing IO Mapping - IO: 360
# Processing IO Mapping - IO: 361
# Processing IO Mapping - IO: 362
# Processing IO Mapping - IO: 363
# Processing IO Mapping - IO: 364
# Processing IO Mapping - IO: 365
# Processing IO Mapping - IO: 366
# Processing IO Mapping - IO: 367
# Processing IO Mapping - IO: 368
# Processing IO Mapping - IO: 369
# Processing IO Mapping - IO: 370
# Processing IO Mapping - IO: 371
# Processing IO Mapping - IO: 372
# Processing IO Mapping - IO: 373
# Processing IO Mapping - IO: 374
# Processing IO Mapping - IO: 375
# Processing IO Mapping - IO: 376
# Processing IO Mapping - IO: 377
# Processing IO Mapping - IO: 378
# Processing IO Mapping - IO: 379
# Processing IO Mapping - IO: 380
# Processing IO Mapping - IO: 381
# Processing IO Mapping - IO: 382
# Processing IO Mapping - IO: 383
# Processing IO Mapping - IO: 384
# Processing IO Mapping - IO: 385
# Processing IO Mapping - IO: 386
# Processing IO Mapping - IO: 387
# Processing IO Mapping - IO: 388
# Processing IO Mapping - IO: 389
# Processing IO Mapping - IO: 390
# Processing IO Mapping - IO: 391
# Processing IO Mapping - IO: 392
# Processing IO Mapping - IO: 393
# Processing IO Mapping - IO: 394
# Processing IO Mapping - IO: 395
# Processing IO Mapping - IO: 396
# Processing IO Mapping - IO: 397
# Processing IO Mapping - IO: 398
# Processing IO Mapping - IO: 399
# Processing IO Mapping - IO: 400
# Processing IO Mapping - IO: 401
# Processing IO Mapping - IO: 402
# Processing IO Mapping - IO: 403
# Processing IO Mapping - IO: 404
# Processing IO Mapping - IO: 405
# Processing IO Mapping - IO: 406
# Processing IO Mapping - IO: 407
# Processing IO Mapping - IO: 408
# Processing IO Mapping - IO: 409
# Processing IO Mapping - IO: 410
# Processing IO Mapping - IO: 411
# Processing IO Mapping - IO: 412
# Processing IO Mapping - IO: 413
# Processing IO Mapping - IO: 414
# Processing IO Mapping - IO: 415
# Processing IO Mapping - IO: 416
# Processing IO Mapping - IO: 417
# Processing IO Mapping - IO: 418
# Processing IO Mapping - IO: 419
# Processing IO Mapping - IO: 420
# Processing IO Mapping - IO: 421
# Processing IO Mapping - IO: 422
# Processing IO Mapping - IO: 423
# Processing IO Mapping - IO: 424
# Processing IO Mapping - IO: 425
# Processing IO Mapping - IO: 426
# Processing IO Mapping - IO: 427
# Processing IO Mapping - IO: 428
# Processing IO Mapping - IO: 429
# Processing IO Mapping - IO: 430
# Processing IO Mapping - IO: 431
# Processing IO Mapping - IO: 432
# Processing IO Mapping - IO: 433
# Processing IO Mapping - IO: 434
# Processing IO Mapping - IO: 435
# Processing IO Mapping - IO: 436
# Processing IO Mapping - IO: 437
# Processing IO Mapping - IO: 438
# Processing IO Mapping - IO: 439
# Processing IO Mapping - IO: 440
# Processing IO Mapping - IO: 441
# Processing IO Mapping - IO: 442
# Processing IO Mapping - IO: 443
# Processing IO Mapping - IO: 444
# Processing IO Mapping - IO: 445
# Processing IO Mapping - IO: 446
# Processing IO Mapping - IO: 447
# Processing IO Mapping - IO: 448
# Processing IO Mapping - IO: 449
# Processing IO Mapping - IO: 450
# Processing IO Mapping - IO: 451
# Processing IO Mapping - IO: 452
# Processing IO Mapping - IO: 453
# Processing IO Mapping - IO: 454
# Processing IO Mapping - IO: 455
# Processing IO Mapping - IO: 456
# Processing IO Mapping - IO: 457
# Processing IO Mapping - IO: 458
# Processing IO Mapping - IO: 459
# Processing IO Mapping - IO: 460
# Processing IO Mapping - IO: 461
# Processing IO Mapping - IO: 462
# Processing IO Mapping - IO: 463
# Processing IO Mapping - IO: 464
# Processing IO Mapping - IO: 465
# Processing IO Mapping - IO: 466
# Processing IO Mapping - IO: 467
# Processing IO Mapping - IO: 468
# Processing IO Mapping - IO: 469
# Processing IO Mapping - IO: 470
# Processing IO Mapping - IO: 471
# Processing IO Mapping - IO: 472
# Processing IO Mapping - IO: 473
# Processing IO Mapping - IO: 474
# Processing IO Mapping - IO: 475
# Processing IO Mapping - IO: 476
# Processing IO Mapping - IO: 477
# Processing IO Mapping - IO: 478
# Processing IO Mapping - IO: 479
# Processing IO Mapping - IO: 480
# Processing IO Mapping - IO: 481
# Processing IO Mapping - IO: 482
# Processing IO Mapping - IO: 483
# Processing IO Mapping - IO: 484
# Processing IO Mapping - IO: 485
# Processing IO Mapping - IO: 486
# Processing IO Mapping - IO: 487
# Processing IO Mapping - IO: 488
# Processing IO Mapping - IO: 489
# Processing IO Mapping - IO: 490
# Processing IO Mapping - IO: 491
# Processing IO Mapping - IO: 492
# Processing IO Mapping - IO: 493
# Processing IO Mapping - IO: 494
# Processing IO Mapping - IO: 495
# Processing IO Mapping - IO: 496
# Processing IO Mapping - IO: 497
# Processing IO Mapping - IO: 498
# Processing IO Mapping - IO: 499
# Processing IO Mapping - IO: 500
# Processing IO Mapping - IO: 501
# Processing IO Mapping - IO: 502
# Processing IO Mapping - IO: 503
# Processing IO Mapping - IO: 504
# Processing IO Mapping - IO: 505
# Processing IO Mapping - IO: 506
# Processing IO Mapping - IO: 507
# Processing IO Mapping - IO: 508
# Processing IO Mapping - IO: 509
# Processing IO Mapping - IO: 510
# Processing IO Mapping - IO: 511
# Processing IO Mapping - IO: 512
# Processing IO Mapping - IO: 513
# Processing IO Mapping - IO: 514
# Processing IO Mapping - IO: 515
# Processing IO Mapping - IO: 516
# Processing IO Mapping - IO: 517
# Processing IO Mapping - IO: 518
# Processing IO Mapping - IO: 519
# Processing IO Mapping - IO: 520
# Processing IO Mapping - IO: 521
# Processing IO Mapping - IO: 522
# Processing IO Mapping - IO: 523
# Processing IO Mapping - IO: 524
# Processing IO Mapping - IO: 525
# Processing IO Mapping - IO: 526
# Processing IO Mapping - IO: 527
# Processing IO Mapping - IO: 528
# Processing IO Mapping - IO: 529
# Processing IO Mapping - IO: 530
# Processing IO Mapping - IO: 531
# Processing IO Mapping - IO: 532
# Processing IO Mapping - IO: 533
# Processing IO Mapping - IO: 534
# Processing IO Mapping - IO: 535
# Processing IO Mapping - IO: 536
# Processing IO Mapping - IO: 537
# Processing IO Mapping - IO: 538
# Processing IO Mapping - IO: 539
# Processing IO Mapping - IO: 540
# Processing IO Mapping - IO: 541
# Processing IO Mapping - IO: 542
# Processing IO Mapping - IO: 543
# Processing IO Mapping - IO: 544
# Processing IO Mapping - IO: 545
# Processing IO Mapping - IO: 546
# Processing IO Mapping - IO: 547
# Processing IO Mapping - IO: 548
# Processing IO Mapping - IO: 549
# Processing IO Mapping - IO: 550
# Processing IO Mapping - IO: 551
# Processing IO Mapping - IO: 552
# Processing IO Mapping - IO: 553
# Processing IO Mapping - IO: 554
# Processing IO Mapping - IO: 555
# Processing IO Mapping - IO: 556
# Processing IO Mapping - IO: 557
# Processing IO Mapping - IO: 558
# Processing IO Mapping - IO: 559
# Processing IO Mapping - IO: 560
# Processing IO Mapping - IO: 561
# Processing IO Mapping - IO: 562
# Processing IO Mapping - IO: 563
# Processing IO Mapping - IO: 564
# Processing IO Mapping - IO: 565
# Processing IO Mapping - IO: 566
# Processing IO Mapping - IO: 567
# Processing IO Mapping - IO: 568
# Processing IO Mapping - IO: 569
# Processing IO Mapping - IO: 570
# Processing IO Mapping - IO: 571
# Processing IO Mapping - IO: 572
# Processing IO Mapping - IO: 573
# Processing IO Mapping - IO: 574
# Processing IO Mapping - IO: 575
# Processing IO Mapping - IO: 576
# Processing IO Mapping - IO: 577
# Processing IO Mapping - IO: 578
# Processing IO Mapping - IO: 579
# Processing IO Mapping - IO: 580
# Processing IO Mapping - IO: 581
# Processing IO Mapping - IO: 582
# Processing IO Mapping - IO: 583
# Processing IO Mapping - IO: 584
# Processing IO Mapping - IO: 585
# Processing IO Mapping - IO: 586
# Processing IO Mapping - IO: 587
# Processing IO Mapping - IO: 588
# Processing IO Mapping - IO: 589
# Processing IO Mapping - IO: 590
# Processing IO Mapping - IO: 591
# Processing IO Mapping - IO: 592
# Processing IO Mapping - IO: 593
# Processing IO Mapping - IO: 594
# Processing IO Mapping - IO: 595
# Processing IO Mapping - IO: 596
# Processing IO Mapping - IO: 597
# Processing IO Mapping - IO: 598
# Processing IO Mapping - IO: 599
# Processing IO Mapping - IO: 600
# Processing IO Mapping - IO: 601
# Processing IO Mapping - IO: 602
# Processing IO Mapping - IO: 603
# Processing IO Mapping - IO: 604
# Processing IO Mapping - IO: 605
# Processing IO Mapping - IO: 606
# Processing IO Mapping - IO: 607
# Processing IO Mapping - IO: 608
# Processing IO Mapping - IO: 609
# Processing IO Mapping - IO: 610
# Processing IO Mapping - IO: 611
# Processing IO Mapping - IO: 612
# Processing IO Mapping - IO: 613
# Processing IO Mapping - IO: 614
# Processing IO Mapping - IO: 615
# Processing IO Mapping - IO: 616
# Processing IO Mapping - IO: 617
# Processing IO Mapping - IO: 618
# Processing IO Mapping - IO: 619
# Processing IO Mapping - IO: 620
# Processing IO Mapping - IO: 621
# Processing IO Mapping - IO: 622
# Processing IO Mapping - IO: 623
# Processing IO Mapping - IO: 624
# Processing IO Mapping - IO: 625
# Processing IO Mapping - IO: 626
# Processing IO Mapping - IO: 627
# Processing IO Mapping - IO: 628
# Processing IO Mapping - IO: 629
# Processing IO Mapping - IO: 630
# Processing IO Mapping - IO: 631
# Processing IO Mapping - IO: 632
# Processing IO Mapping - IO: 633
# Processing IO Mapping - IO: 634
# Processing IO Mapping - IO: 635
# Processing IO Mapping - IO: 636
# Processing IO Mapping - IO: 637
# Processing IO Mapping - IO: 638
# Processing IO Mapping - IO: 639
# Processing IO Mapping - IO: 640
# Processing IO Mapping - IO: 641
# Processing IO Mapping - IO: 642
# Processing IO Mapping - IO: 643
# Processing IO Mapping - IO: 644
# Processing IO Mapping - IO: 645
# Processing IO Mapping - IO: 646
# Processing IO Mapping - IO: 647
# Processing IO Mapping - IO: 648
# Processing IO Mapping - IO: 649
# Processing IO Mapping - IO: 650
# Processing IO Mapping - IO: 651
# Processing IO Mapping - IO: 652
# Processing IO Mapping - IO: 653
# Processing IO Mapping - IO: 654
# Processing IO Mapping - IO: 655
# Processing IO Mapping - IO: 656
# Processing IO Mapping - IO: 657
# Processing IO Mapping - IO: 658
